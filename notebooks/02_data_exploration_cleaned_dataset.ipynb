# %% [markdown]
# # Dataset Exploration
# **Dataset:** `sales_with_converted_rents_enriched_with_arbk.xlsx`
#
# This notebook analyzes:
# 1. Data types
# 2. Null and non-null values
# 3. Data quality (duplicate rows, ARBK match rate, cardinality)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker
import warnings
import matplotlib.pyplot as plt


import matplotlib.pyplot as plt

def plot_outliers(df):
    numeric_cols = df.select_dtypes(include='number').columns
    
    for col in numeric_cols:
        plt.figure()
        plt.boxplot(df[col].dropna())
        plt.title(f"Outliers in {col}")
        plt.ylabel(col)
        plt.show()

warnings.filterwarnings('ignore')

plt.rcParams['figure.dpi'] = 80
plt.rcParams['font.size'] = 10

# %%
FILE = '..\data\processed\property_buyer\cleaned_dataset_no_missing_v1.0.xlsx'

df = pd.read_excel(FILE, engine='openpyxl')

print(f'Rows   : {len(df)}')
print(f'Columns: {len(df.columns)}')
# Out:
# Rows   : 3483
# Columns: 47

# %% [markdown]
# ---
# ## 1. Data Types
